# %%
# import the necessary packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import os
import random
import shutil
from scipy import ndimage
# from joblib import Parallel, delayed
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split

# %%
sub_window_and_count_path = 'final_train_sub_windows_and_counts'
# load the data

# subwindow data
X_train = np.load('final_train_sub_windows_and_counts/train_sub_windows.npy')
print(X_train.shape)

# sub counts data
y_train = np.load('final_train_sub_windows_and_counts/train_sub_counts.npy')
print(y_train.shape)

# subwindow data
X_valid = np.load('final_valid_sub_windows_and_counts/valid_sub_windows.npy')
print(X_valid.shape)

# sub counts data
y_valid = np.load('final_valid_sub_windows_and_counts/valid_sub_counts.npy')
print(y_valid.shape)
# Out:
# (1572864, 32, 32, 3)
# (1572864,)
# (393216, 32, 32, 3)
# (393216,)

# %%
# load and add the new layers to the prev trained model
TN_model = tf.keras.models.load_model('../models/tasselnet1_overlapping_w32.h5')
# look at the input shape
TN_model.input
# need to remove some of the last layers
output_trial = TN_model.layers[-8].output
    
# create the functional API model
reduced_model = tf.keras.models.Model(TN_model.input, output_trial)

# %%
reduced_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_input (InputLayer)   [(None, 32, 32, 3)]       0
#
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  activation_1 (Activation)   (None, 30, 30, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  activation_2 (Activation)   (None, 15, 15, 64)        0
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  activation_3 (Activation)   (None, 13, 13, 64)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
# =================================================================
# Total params: 65,568
# Trainable params: 65,568
# Non-trainable params: 0
# _________________________________________________________________

# %%
# add dropout
added_dropout = tf.keras.layers.Dropout(0.5, name = "New_dropout")(TN_model.layers[-8].output)

# add flatten
added_flatten = tf.keras.layers.Flatten(name = "Flatten2")(added_dropout)

# add dense
added_dense = tf.keras.layers.Dense(512, name = "New_Dense")(added_flatten)

# add activation
added_Act = tf.keras.layers.Activation('relu', name = "New_Activation")(added_dense)

# add dropout
added_dropout2 = tf.keras.layers.Dropout(0.5, name = "New_dropout2")(added_Act)

# add dense
added_dense2 = tf.keras.layers.Dense(1, name = "New_Dense2")(added_dropout2)

# add activation
added_Act2 = tf.keras.layers.Activation('relu', name = "New_Activation2")(added_dense2)

# define the new model with functional API
new_model = tf.keras.models.Model(TN_model.input, added_Act2)

# %%
def data_generator(x_data, y_data, batch_size, shuffle=False, peek=False, verbose=False):
    num_samples = len(x_data)
    indices = np.arange(num_samples)
    
    if peek:    # Give first batch unshuffled and don't change start index when peeking for training
        end = min(batch_size, num_samples)
        if verbose:
            print(f"Generating peeking batch up to index {end}")
        batch_x = x_data[:end]
        batch_y = y_data[:end]
        peek = False
        yield (batch_x, batch_y)

    while True:    # Loop indefinitely for epochs
        # Shuffle indices at the start of each epoch after the peek, if shuffle is enabled
        if shuffle:
            np.random.shuffle(indices)
        
        for start in range(0, num_samples, batch_size):
            end = min(start + batch_size, num_samples)
            batch_indices = indices[start:end]

            # Print batch indices if verbose
            if verbose:
                # Warning: calling verbose when shuffling will usually clutter output
                if shuffle:
                    if len(batch_indices) < 16:
                        print(f"Batch indices: {np.sort(batch_indices)}")
                    else:
                        print(f"Printing batch indices would clutter output. Skipped.")
                    print(f"Length: {len(batch_indices)}")
                else:
                    print(f"Generating batch from index {start} to {end}")
                # traceback.print_stack()

            # Generate batches
            batch_x = x_data[batch_indices]
            batch_y = y_data[batch_indices]

            # Yield the current batch
            yield (batch_x, batch_y)

# %%
# %%time
batch_size = 1024
generator_batch_size = 1024
train_gen = data_generator(X_train, y_train, batch_size, shuffle=False, peek=True, verbose=False)
val_gen = data_generator(X_valid, y_valid, generator_batch_size, shuffle=False, peek=True, verbose=False)
# Out:
# CPU times: user 1 µs, sys: 6 µs, total: 7 µs
# Wall time: 11.4 µs

# %%
steps_per_epoch = int(np.ceil(len(X_train) / batch_size))
train_steps = int(np.ceil(len(X_train) / generator_batch_size))
validation_steps = int(np.ceil(len(X_valid) / generator_batch_size))

# %%
#     freeze layers
for layer in TN_model.layers:
    layer.trainable = False
    
# compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
new_model.compile(loss='mean_squared_error', optimizer=opt, metrics = ['mean_absolute_error'])
    
# add early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', restore_best_weights = True, verbose=1, patience=10)

#     fit the frozen model:
history = new_model.fit(train_gen,
          validation_data = val_gen, steps_per_epoch=steps_per_epoch, 
                                  validation_steps=validation_steps,                        
          epochs = 100, callbacks = [es])
# Out:
# Epoch 1/100
# 1536/1536 [==============================] - 28s 15ms/step - loss: 0.0262 - mean_absolute_error: 0.0627 - val_loss: 0.0206 - val_mean_absolute_error: 0.0340
# Epoch 2/100
# 1536/1536 [==============================] - 24s 15ms/step - loss: 0.0252 - mean_absolute_error: 0.0613 - val_loss: 0.0203 - val_mean_absolute_error: 0.0351
# Epoch 3/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0249 - mean_absolute_error: 0.0614 - val_loss: 0.0200 - val_mean_absolute_error: 0.0375
# Epoch 4/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0247 - mean_absolute_error: 0.0616 - val_loss: 0.0198 - val_mean_absolute_error: 0.0391
# Epoch 5/100
# 1536/1536 [==============================] - 24s 16ms/step - loss: 0.0246 - mean_absolute_error: 0.0614 - val_loss: 0.0197 - val_mean_absolute_error: 0.0396
# Epoch 6/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0245 - mean_absolute_error: 0.0612 - val_loss: 0.0195 - val_mean_absolute_error: 0.0408
# Epoch 7/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0244 - mean_absolute_error: 0.0610 - val_loss: 0.0195 - val_mean_absolute_error: 0.0412
# Epoch 8/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0243 - mean_absolute_error: 0.0607 - val_loss: 0.0194 - val_mean_absolute_error: 0.0414
# Epoch 9/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0242 - mean_absolute_error: 0.0604 - val_loss: 0.0193 - val_mean_absolute_error: 0.0415
# Epoch 10/100
# 1536/1536 [==============================] - 24s 15ms/step - loss: 0.0241 - mean_absolute_error: 0.0602 - val_loss: 0.0193 - val_mean_absolute_error: 0.0420
# Epoch 11/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0240 - mean_absolute_error: 0.0599 - val_loss: 0.0192 - val_mean_absolute_error: 0.0413
# Epoch 12/100
# 1536/1536 [==============================] - 24s 15ms/step - loss: 0.0240 - mean_absolute_error: 0.0598 - val_loss: 0.0192 - val_mean_absolute_error: 0.0411
# Epoch 13/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0239 - mean_absolute_error: 0.0596 - val_loss: 0.0191 - val_mean_absolute_error: 0.0415
# Epoch 14/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0239 - mean_absolute_error: 0.0594 - val_loss: 0.0191 - val_mean_absolute_error: 0.0410
# Epoch 15/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0239 - mean_absolute_error: 0.0593 - val_loss: 0.0190 - val_mean_absolute_error: 0.0413
# Epoch 16/100
# 1536/1536 [==============================] - 24s 16ms/step - loss: 0.0238 - mean_absolute_error: 0.0591 - val_loss: 0.0190 - val_mean_absolute_error: 0.0415
# Epoch 17/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0238 - mean_absolute_error: 0.0590 - val_loss: 0.0189 - val_mean_absolute_error: 0.0407
# Epoch 18/100
# 1536/1536 [==============================] - 24s 16ms/step - loss: 0.0237 - mean_absolute_error: 0.0589 - val_loss: 0.0189 - val_mean_absolute_error: 0.0412
# Epoch 19/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0237 - mean_absolute_error: 0.0589 - val_loss: 0.0189 - val_mean_absolute_error: 0.0413
# Epoch 20/100
# 1536/1536 [==============================] - 24s 16ms/step - loss: 0.0237 - mean_absolute_error: 0.0587 - val_loss: 0.0189 - val_mean_absolute_error: 0.0411
# Epoch 21/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0237 - mean_absolute_error: 0.0585 - val_loss: 0.0188 - val_mean_absolute_error: 0.0408
# Epoch 22/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0236 - mean_absolute_error: 0.0584 - val_loss: 0.0188 - val_mean_absolute_error: 0.0408
# Epoch 23/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0236 - mean_absolute_error: 0.0583 - val_loss: 0.0188 - val_mean_absolute_error: 0.0411
# Epoch 24/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0236 - mean_absolute_error: 0.0582 - val_loss: 0.0188 - val_mean_absolute_error: 0.0403
# Epoch 25/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0236 - mean_absolute_error: 0.0582 - val_loss: 0.0187 - val_mean_absolute_error: 0.0406
# Epoch 26/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0235 - mean_absolute_error: 0.0582 - val_loss: 0.0188 - val_mean_absolute_error: 0.0405
# Epoch 27/100
# 1536/1536 [==============================] - 24s 16ms/step - loss: 0.0235 - mean_absolute_error: 0.0581 - val_loss: 0.0187 - val_mean_absolute_error: 0.0406
# Epoch 28/100
# 1536/1536 [==============================] - 24s 16ms/step - loss: 0.0235 - mean_absolute_error: 0.0580 - val_loss: 0.0187 - val_mean_absolute_error: 0.0405
# Epoch 29/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0235 - mean_absolute_error: 0.0580 - val_loss: 0.0187 - val_mean_absolute_error: 0.0408
# Epoch 30/100
# 1536/1536 [==============================] - 24s 16ms/step - loss: 0.0235 - mean_absolute_error: 0.0579 - val_loss: 0.0187 - val_mean_absolute_error: 0.0401
# Epoch 31/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0235 - mean_absolute_error: 0.0578 - val_loss: 0.0187 - val_mean_absolute_error: 0.0400
# Epoch 32/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0234 - mean_absolute_error: 0.0578 - val_loss: 0.0187 - val_mean_absolute_error: 0.0402
# Epoch 33/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0234 - mean_absolute_error: 0.0577 - val_loss: 0.0187 - val_mean_absolute_error: 0.0398
# Epoch 34/100
# 1536/1536 [==============================] - 24s 15ms/step - loss: 0.0234 - mean_absolute_error: 0.0576 - val_loss: 0.0187 - val_mean_absolute_error: 0.0400
# Epoch 35/100
# 1536/1536 [==============================] - 24s 15ms/step - loss: 0.0234 - mean_absolute_error: 0.0575 - val_loss: 0.0186 - val_mean_absolute_error: 0.0401
# Epoch 36/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0234 - mean_absolute_error: 0.0575 - val_loss: 0.0186 - val_mean_absolute_error: 0.0400
# Epoch 37/100
# 1536/1536 [==============================] - 24s 16ms/step - loss: 0.0234 - mean_absolute_error: 0.0575 - val_loss: 0.0186 - val_mean_absolute_error: 0.0400
# Epoch 38/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0234 - mean_absolute_error: 0.0575 - val_loss: 0.0186 - val_mean_absolute_error: 0.0402
# Epoch 39/100
# 1536/1536 [==============================] - 24s 15ms/step - loss: 0.0233 - mean_absolute_error: 0.0574 - val_loss: 0.0186 - val_mean_absolute_error: 0.0397
# Epoch 40/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0233 - mean_absolute_error: 0.0573 - val_loss: 0.0186 - val_mean_absolute_error: 0.0396
# Epoch 41/100
# 1536/1536 [==============================] - 22s 15ms/step - loss: 0.0234 - mean_absolute_error: 0.0573 - val_loss: 0.0186 - val_mean_absolute_error: 0.0398
# Epoch 42/100
# 1536/1536 [==============================] - 24s 15ms/step - loss: 0.0233 - mean_absolute_error: 0.0572 - val_loss: 0.0186 - val_mean_absolute_error: 0.0400
# Epoch 43/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0233 - mean_absolute_error: 0.0572 - val_loss: 0.0186 - val_mean_absolute_error: 0.0402
# Epoch 44/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0233 - mean_absolute_error: 0.0572 - val_loss: 0.0186 - val_mean_absolute_error: 0.0399
# Epoch 45/100
# 1536/1536 [==============================] - 24s 15ms/step - loss: 0.0233 - mean_absolute_error: 0.0572 - val_loss: 0.0186 - val_mean_absolute_error: 0.0401
# Epoch 46/100
# 1536/1536 [==============================] - 24s 15ms/step - loss: 0.0233 - mean_absolute_error: 0.0570 - val_loss: 0.0186 - val_mean_absolute_error: 0.0399
# Epoch 47/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0233 - mean_absolute_error: 0.0571 - val_loss: 0.0186 - val_mean_absolute_error: 0.0397
# Epoch 48/100
# 1536/1536 [==============================] - 24s 16ms/step - loss: 0.0232 - mean_absolute_error: 0.0570 - val_loss: 0.0185 - val_mean_absolute_error: 0.0402
# Epoch 49/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0232 - mean_absolute_error: 0.0569 - val_loss: 0.0185 - val_mean_absolute_error: 0.0401
# Epoch 50/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0232 - mean_absolute_error: 0.0569 - val_loss: 0.0186 - val_mean_absolute_error: 0.0396
# Epoch 51/100
# 1536/1536 [==============================] - 24s 16ms/step - loss: 0.0232 - mean_absolute_error: 0.0570 - val_loss: 0.0185 - val_mean_absolute_error: 0.0402
# Epoch 52/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0232 - mean_absolute_error: 0.0568 - val_loss: 0.0185 - val_mean_absolute_error: 0.0396
# Epoch 53/100
# 1536/1536 [==============================] - 24s 15ms/step - loss: 0.0232 - mean_absolute_error: 0.0568 - val_loss: 0.0185 - val_mean_absolute_error: 0.0403
# Epoch 54/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0232 - mean_absolute_error: 0.0569 - val_loss: 0.0185 - val_mean_absolute_error: 0.0397
# Epoch 55/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0232 - mean_absolute_error: 0.0567 - val_loss: 0.0185 - val_mean_absolute_error: 0.0399
# Epoch 56/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0232 - mean_absolute_error: 0.0568 - val_loss: 0.0185 - val_mean_absolute_error: 0.0395
# Epoch 57/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0232 - mean_absolute_error: 0.0569 - val_loss: 0.0185 - val_mean_absolute_error: 0.0395
# Epoch 58/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0232 - mean_absolute_error: 0.0568 - val_loss: 0.0185 - val_mean_absolute_error: 0.0400
# Epoch 59/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0231 - mean_absolute_error: 0.0567 - val_loss: 0.0185 - val_mean_absolute_error: 0.0399
# Epoch 60/100
# 1536/1536 [==============================] - 24s 15ms/step - loss: 0.0232 - mean_absolute_error: 0.0567 - val_loss: 0.0185 - val_mean_absolute_error: 0.0395
# Epoch 61/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0232 - mean_absolute_error: 0.0567 - val_loss: 0.0185 - val_mean_absolute_error: 0.0400
# Epoch 62/100
# 1536/1536 [==============================] - 24s 16ms/step - loss: 0.0231 - mean_absolute_error: 0.0566 - val_loss: 0.0185 - val_mean_absolute_error: 0.0399
# Epoch 63/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0231 - mean_absolute_error: 0.0566 - val_loss: 0.0185 - val_mean_absolute_error: 0.0398
# Epoch 64/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0231 - mean_absolute_error: 0.0566 - val_loss: 0.0185 - val_mean_absolute_error: 0.0399
# Epoch 65/100
# 1536/1536 [==============================] - 24s 16ms/step - loss: 0.0231 - mean_absolute_error: 0.0567 - val_loss: 0.0185 - val_mean_absolute_error: 0.0398
# Epoch 66/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0231 - mean_absolute_error: 0.0566 - val_loss: 0.0185 - val_mean_absolute_error: 0.0401
# Epoch 67/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0232 - mean_absolute_error: 0.0566 - val_loss: 0.0185 - val_mean_absolute_error: 0.0399
# Epoch 68/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0231 - mean_absolute_error: 0.0566 - val_loss: 0.0185 - val_mean_absolute_error: 0.0396
# Epoch 69/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0231 - mean_absolute_error: 0.0565 - val_loss: 0.0185 - val_mean_absolute_error: 0.0401
# Epoch 70/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0231 - mean_absolute_error: 0.0565 - val_loss: 0.0185 - val_mean_absolute_error: 0.0398
# Epoch 71/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0231 - mean_absolute_error: 0.0564 - val_loss: 0.0185 - val_mean_absolute_error: 0.0403
# Epoch 72/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0231 - mean_absolute_error: 0.0564 - val_loss: 0.0185 - val_mean_absolute_error: 0.0400
# Epoch 73/100
# 1536/1536 [==============================] - 24s 15ms/step - loss: 0.0230 - mean_absolute_error: 0.0563 - val_loss: 0.0185 - val_mean_absolute_error: 0.0400
# Epoch 74/100
# 1536/1536 [==============================] - 24s 16ms/step - loss: 0.0231 - mean_absolute_error: 0.0564 - val_loss: 0.0185 - val_mean_absolute_error: 0.0401
# Epoch 75/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0231 - mean_absolute_error: 0.0564 - val_loss: 0.0185 - val_mean_absolute_error: 0.0398
# Epoch 76/100
# 1536/1536 [==============================] - 24s 16ms/step - loss: 0.0231 - mean_absolute_error: 0.0563 - val_loss: 0.0185 - val_mean_absolute_error: 0.0400
# Epoch 77/100
# 1536/1536 [==============================] - 24s 15ms/step - loss: 0.0231 - mean_absolute_error: 0.0563 - val_loss: 0.0185 - val_mean_absolute_error: 0.0400
# Epoch 78/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0230 - mean_absolute_error: 0.0562 - val_loss: 0.0185 - val_mean_absolute_error: 0.0402
# Epoch 79/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0230 - mean_absolute_error: 0.0563 - val_loss: 0.0185 - val_mean_absolute_error: 0.0393
# Epoch 80/100
# 1536/1536 [==============================] - 24s 15ms/step - loss: 0.0230 - mean_absolute_error: 0.0563 - val_loss: 0.0185 - val_mean_absolute_error: 0.0399
# Epoch 81/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0230 - mean_absolute_error: 0.0562 - val_loss: 0.0185 - val_mean_absolute_error: 0.0399
# Epoch 82/100
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0230 - mean_absolute_error: 0.0561 - val_loss: 0.0185 - val_mean_absolute_error: 0.0399
# Epoch 83/100
# 1536/1536 [==============================] - 24s 16ms/step - loss: 0.0230 - mean_absolute_error: 0.0562 - val_loss: 0.0185 - val_mean_absolute_error: 0.0402
# Epoch 84/100
# 1533/1536 [============================>.] - ETA: 0s - loss: 0.0230 - mean_absolute_error: 0.0562Restoring model weights from the end of the best epoch: 74.
# 1536/1536 [==============================] - 23s 15ms/step - loss: 0.0230 - mean_absolute_error: 0.0562 - val_loss: 0.0185 - val_mean_absolute_error: 0.0398
# Epoch 84: early stopping

# %%
# # unfreeze few layers and retrain - finetune the model
TN_model.trainable = True

set_trainable = False

for layer in TN_model.layers:
    if layer.name == 'conv2d_3':
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
            
    # # compile the mdoel
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
new_model.compile(loss='mean_squared_error', optimizer=opt, metrics = ['mean_absolute_error'])
    
    # # add early stopping
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', restore_best_weights = True, verbose=1, patience=10)
    
    # # fit the model (fine tuned)
history_new = new_model.fit(train_gen,
          validation_data = val_gen, steps_per_epoch=steps_per_epoch, 
                                  validation_steps=validation_steps,                        
          epochs = 100, callbacks = [es])
# Out:
# Epoch 1/100
# 1536/1536 [==============================] - 26s 16ms/step - loss: 0.0223 - mean_absolute_error: 0.0531 - val_loss: 0.0186 - val_mean_absolute_error: 0.0376
# Epoch 2/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0218 - mean_absolute_error: 0.0521 - val_loss: 0.0186 - val_mean_absolute_error: 0.0386
# Epoch 3/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0215 - mean_absolute_error: 0.0516 - val_loss: 0.0182 - val_mean_absolute_error: 0.0379
# Epoch 4/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0212 - mean_absolute_error: 0.0512 - val_loss: 0.0181 - val_mean_absolute_error: 0.0368
# Epoch 5/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0211 - mean_absolute_error: 0.0511 - val_loss: 0.0177 - val_mean_absolute_error: 0.0367
# Epoch 6/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0209 - mean_absolute_error: 0.0508 - val_loss: 0.0178 - val_mean_absolute_error: 0.0368
# Epoch 7/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0207 - mean_absolute_error: 0.0506 - val_loss: 0.0179 - val_mean_absolute_error: 0.0359
# Epoch 8/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0207 - mean_absolute_error: 0.0505 - val_loss: 0.0174 - val_mean_absolute_error: 0.0363
# Epoch 9/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0205 - mean_absolute_error: 0.0503 - val_loss: 0.0174 - val_mean_absolute_error: 0.0367
# Epoch 10/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0204 - mean_absolute_error: 0.0501 - val_loss: 0.0173 - val_mean_absolute_error: 0.0362
# Epoch 11/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0203 - mean_absolute_error: 0.0500 - val_loss: 0.0172 - val_mean_absolute_error: 0.0358
# Epoch 12/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0202 - mean_absolute_error: 0.0498 - val_loss: 0.0173 - val_mean_absolute_error: 0.0355
# Epoch 13/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0201 - mean_absolute_error: 0.0496 - val_loss: 0.0175 - val_mean_absolute_error: 0.0356
# Epoch 14/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0202 - mean_absolute_error: 0.0496 - val_loss: 0.0172 - val_mean_absolute_error: 0.0361
# Epoch 15/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0200 - mean_absolute_error: 0.0494 - val_loss: 0.0171 - val_mean_absolute_error: 0.0360
# Epoch 16/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0199 - mean_absolute_error: 0.0492 - val_loss: 0.0172 - val_mean_absolute_error: 0.0359
# Epoch 17/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0199 - mean_absolute_error: 0.0490 - val_loss: 0.0171 - val_mean_absolute_error: 0.0361
# Epoch 18/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0198 - mean_absolute_error: 0.0490 - val_loss: 0.0170 - val_mean_absolute_error: 0.0368
# Epoch 19/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0197 - mean_absolute_error: 0.0488 - val_loss: 0.0171 - val_mean_absolute_error: 0.0359
# Epoch 20/100
# 1536/1536 [==============================] - 27s 17ms/step - loss: 0.0196 - mean_absolute_error: 0.0488 - val_loss: 0.0172 - val_mean_absolute_error: 0.0357
# Epoch 21/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0196 - mean_absolute_error: 0.0486 - val_loss: 0.0169 - val_mean_absolute_error: 0.0369
# Epoch 22/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0196 - mean_absolute_error: 0.0485 - val_loss: 0.0169 - val_mean_absolute_error: 0.0355
# Epoch 23/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0196 - mean_absolute_error: 0.0486 - val_loss: 0.0169 - val_mean_absolute_error: 0.0356
# Epoch 24/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0195 - mean_absolute_error: 0.0484 - val_loss: 0.0168 - val_mean_absolute_error: 0.0359
# Epoch 25/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0195 - mean_absolute_error: 0.0483 - val_loss: 0.0168 - val_mean_absolute_error: 0.0353
# Epoch 26/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0194 - mean_absolute_error: 0.0482 - val_loss: 0.0167 - val_mean_absolute_error: 0.0358
# Epoch 27/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0194 - mean_absolute_error: 0.0482 - val_loss: 0.0167 - val_mean_absolute_error: 0.0361
# Epoch 28/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0193 - mean_absolute_error: 0.0481 - val_loss: 0.0167 - val_mean_absolute_error: 0.0365
# Epoch 29/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0192 - mean_absolute_error: 0.0480 - val_loss: 0.0167 - val_mean_absolute_error: 0.0355
# Epoch 30/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0192 - mean_absolute_error: 0.0480 - val_loss: 0.0167 - val_mean_absolute_error: 0.0365
# Epoch 31/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0192 - mean_absolute_error: 0.0480 - val_loss: 0.0165 - val_mean_absolute_error: 0.0369
# Epoch 32/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0192 - mean_absolute_error: 0.0479 - val_loss: 0.0167 - val_mean_absolute_error: 0.0359
# Epoch 33/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0191 - mean_absolute_error: 0.0477 - val_loss: 0.0167 - val_mean_absolute_error: 0.0363
# Epoch 34/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0191 - mean_absolute_error: 0.0478 - val_loss: 0.0165 - val_mean_absolute_error: 0.0359
# Epoch 35/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0190 - mean_absolute_error: 0.0476 - val_loss: 0.0165 - val_mean_absolute_error: 0.0369
# Epoch 36/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0190 - mean_absolute_error: 0.0477 - val_loss: 0.0165 - val_mean_absolute_error: 0.0364
# Epoch 37/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0190 - mean_absolute_error: 0.0475 - val_loss: 0.0167 - val_mean_absolute_error: 0.0357
# Epoch 38/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0190 - mean_absolute_error: 0.0475 - val_loss: 0.0166 - val_mean_absolute_error: 0.0365
# Epoch 39/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0190 - mean_absolute_error: 0.0474 - val_loss: 0.0165 - val_mean_absolute_error: 0.0367
# Epoch 40/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0189 - mean_absolute_error: 0.0473 - val_loss: 0.0165 - val_mean_absolute_error: 0.0357
# Epoch 41/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0189 - mean_absolute_error: 0.0473 - val_loss: 0.0165 - val_mean_absolute_error: 0.0364
# Epoch 42/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0188 - mean_absolute_error: 0.0472 - val_loss: 0.0164 - val_mean_absolute_error: 0.0359
# Epoch 43/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0188 - mean_absolute_error: 0.0472 - val_loss: 0.0166 - val_mean_absolute_error: 0.0360
# Epoch 44/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0188 - mean_absolute_error: 0.0471 - val_loss: 0.0165 - val_mean_absolute_error: 0.0358
# Epoch 45/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0188 - mean_absolute_error: 0.0470 - val_loss: 0.0166 - val_mean_absolute_error: 0.0359
# Epoch 46/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0188 - mean_absolute_error: 0.0471 - val_loss: 0.0166 - val_mean_absolute_error: 0.0355
# Epoch 47/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0187 - mean_absolute_error: 0.0469 - val_loss: 0.0165 - val_mean_absolute_error: 0.0361
# Epoch 48/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0187 - mean_absolute_error: 0.0470 - val_loss: 0.0165 - val_mean_absolute_error: 0.0363
# Epoch 49/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0188 - mean_absolute_error: 0.0470 - val_loss: 0.0164 - val_mean_absolute_error: 0.0365
# Epoch 50/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0187 - mean_absolute_error: 0.0468 - val_loss: 0.0164 - val_mean_absolute_error: 0.0357
# Epoch 51/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0187 - mean_absolute_error: 0.0468 - val_loss: 0.0165 - val_mean_absolute_error: 0.0351
# Epoch 52/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0186 - mean_absolute_error: 0.0467 - val_loss: 0.0165 - val_mean_absolute_error: 0.0354
# Epoch 53/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0186 - mean_absolute_error: 0.0466 - val_loss: 0.0163 - val_mean_absolute_error: 0.0365
# Epoch 54/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0186 - mean_absolute_error: 0.0466 - val_loss: 0.0165 - val_mean_absolute_error: 0.0363
# Epoch 55/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0185 - mean_absolute_error: 0.0465 - val_loss: 0.0163 - val_mean_absolute_error: 0.0365
# Epoch 56/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0186 - mean_absolute_error: 0.0466 - val_loss: 0.0163 - val_mean_absolute_error: 0.0368
# Epoch 57/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0185 - mean_absolute_error: 0.0464 - val_loss: 0.0165 - val_mean_absolute_error: 0.0358
# Epoch 58/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0185 - mean_absolute_error: 0.0464 - val_loss: 0.0165 - val_mean_absolute_error: 0.0354
# Epoch 59/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0185 - mean_absolute_error: 0.0464 - val_loss: 0.0165 - val_mean_absolute_error: 0.0361
# Epoch 60/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0185 - mean_absolute_error: 0.0463 - val_loss: 0.0164 - val_mean_absolute_error: 0.0353
# Epoch 61/100
# 1536/1536 [==============================] - 26s 17ms/step - loss: 0.0185 - mean_absolute_error: 0.0464 - val_loss: 0.0164 - val_mean_absolute_error: 0.0362
# Epoch 62/100
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0184 - mean_absolute_error: 0.0462 - val_loss: 0.0165 - val_mean_absolute_error: 0.0359
# Epoch 63/100
# 1533/1536 [============================>.] - ETA: 0s - loss: 0.0184 - mean_absolute_error: 0.0463Restoring model weights from the end of the best epoch: 53.
# 1536/1536 [==============================] - 25s 16ms/step - loss: 0.0184 - mean_absolute_error: 0.0463 - val_loss: 0.0164 - val_mean_absolute_error: 0.0362
# Epoch 63: early stopping

# %%
# save the finetuned model
model_name = 'TN_model_with_new_data.h5'
new_model.save('models' + '/' + model_name)
